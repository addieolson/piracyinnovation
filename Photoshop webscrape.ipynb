# %% [markdown]
# # Webscraping Adobe Photoshop Version History table with python
# Addie Olson

# %% [markdown]
# First, download the necessary packages: BeautifulSoup, Pandas, and Requests.

# %%
from bs4 import BeautifulSoup

# %%
import requests
import pandas as pd

# %% [markdown]
# Next, pull the xml code from the webpage and identify the tables in the page.

# %%
WIKI_URL = "https://en.wikipedia.org/wiki/Adobe_Photoshop_version_history"

req = requests.get(WIKI_URL)
soup = BeautifulSoup(req.content, 'lxml')
table_classes = {"class": ["wikitable"]}
wikitables = soup.findAll("table", table_classes)

# %% [markdown]
# Build the dataframe, cleaning footnotes and links from the cell contents.

# %%
    rows=wikitables[0].findAll("tr")
    row_lengths=[len(r.findAll(['th','td'])) for r in rows]
    ncols=max(row_lengths)
    nrows=len(rows)
    data=[]
    for i in range(nrows):
        rowD=[]
        for j in range(ncols):
            rowD.append('')
        data.append(rowD)
    
    # process html
    for i in range(len(rows)):
        row=rows[i]
        rowD=[]
        cells = row.findAll(["td","th"])
        for j in range(len(cells)):
            cell=cells[j]
            if '[' in cell:
                cell = cell[:-3]
           
            #lots of cells span cols and rows so lets deal with that
            cspan=int(cell.get('colspan',1))
            rspan=int(cell.get('rowspan',1))
            l = 0
            for k in range(rspan):
                # Shifts to the first empty cell of this row
                while data[i+k][j+l]:
                    l+=1
                for m in range(cspan):
                    data[i+k][j+l+m]+=str(cell.text).strip('\n')
data.append(rowD)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                     0  \
# 0                                             Version
# 1                                                0.07
# 2                                                0.63
# 3                                          0.87\n0.87
# 4                                            1.0\n1.0
# 5                                            2.0\n2.0
# 6                                                 2.5
# 7                                                 2.5
# 8                                                 2.5
# 9                                            3.0\n3.0
# 10                                           3.0\n3.0
# 11                                           4.0\n4.0
# 12                                           5.0\n5.0
# 13                                                5.5
# 14                                           6.0\n6.0
# 15                                           7.0\n7.0
# 16                                              7.0.1
# 17                                 CS (8.0)\nCS (8.0)
# 18                               CS2 (9.0)\nCS2 (9.0)
# 19               CS3 (10.0)\nCS3, CS3 Extended (10.0)
# 20               CS4 (11.0)\nCS4, CS4 Extended (11.0)
# 21               CS5 (12.0)\nCS5, CS5 Extended (12.0)
# 22         CS5.1,[8] CS5.1[8] Extended (12.1, 12.0.4)
# 23  CS6, CS6 Extended (13.0)\nCS6, CS6 Extended (1...
# 24                               CC (14.0)\nCC (14.0)
# 25                               CC (14.1)\nCC (14.1)
# 26                               CC (14.2)\nCC (14.2)
# 27  CC 2014 (15.0 or 20140508.r.58)\nCC 2014 (15.0...
# 28  CC 2014.2.2 (15.2.2 or 20141204.r.310)\nCC 201...
# 29  CC 2015 (16.0 or 20150529.r.88)\nCC 2015 (16.0...
# 30  CC 2015.1 (16.1 or 20151114.r.301)\nCC 2015.1 ...
# 31               CC 2015.1.2 (16.2 or 20160113.r.355)
# 32  CC 2015.5 (17.0 or 20160603.r.88)\nCC 2015.5 (...
# 33  CC 2015.5.1 (17.0.1 or 20160722.r.156)\nCC 201...
# 34  CC 2017 (18.0 or 20161012.r.53)\nCC 2017 (18.0...
# 35  CC 2017.0.1 (18.0.1 or 20161130.r.29)\nCC 2017...
# 36  CC 2017.1.0 (18.1.0 or 20170309.r.207)\nCC 201...
# 37  CC 2017.1.1 (18.1.1 or 20170425.r.252)\nCC 201...
# 38                 CC 2018 (19.0.0)\nCC 2018 (19.0.0)
# 39                 CC 2018 (19.0.1)\nCC 2018 (19.0.1)
# 40                     CC 2018 (19.1)\nCC 2018 (19.1)
# 41                 CC 2018 (19.1.1)\nCC 2018 (19.1.1)
# 42                 CC 2018 (19.1.2)\nCC 2018 (19.1.2)
# 43                 CC 2018 (19.1.3)\nCC 2018 (19.1.3)
# 44                 CC 2018 (19.1.4)\nCC 2018 (19.1.4)
# 45                 CC 2018 (19.1.5)\nCC 2018 (19.1.5)
# 46                 CC 2018 (19.1.6)\nCC 2018 (19.1.6)
# 47                                               None
#
#                                               1  \
# 0                                      Platform
# 1                                     Macintosh
# 2                                     Macintosh
# 3                                     Macintosh
# 4                                     Macintosh
# 5                                     Macintosh
# 6                                     Macintosh
# 7                                       Windows
# 8                                 IRIX, Solaris
# 9                                     Macintosh
# 10                    Windows, IRIX, Solaris[4]
# 11                           Macintosh, Windows
# 12                           Macintosh, Windows
# 13                           Macintosh, Windows
# 14                           Macintosh, Windows
# 15           Mac OS 'Classic'/Mac OS X, Windows
# 16           Mac OS 'Classic'/Mac OS X, Windows
# 17                            Mac OS X, Windows
# 18                  Mac OS X, Windows 2000 / XP
# 19  Universal Mac OS X, Windows XP SP2 or later
# 20  Universal Mac OS X, Windows XP SP2 or later
# 21            Mac OS X, Windows XP SP3 or newer
# 22            Mac OS X, Windows XP SP3 or newer
# 23            Mac OS X, Windows XP SP3 or newer
# 24                 Mac OS X, Windows 7 or newer
# 25                 Mac OS X, Windows 7 or newer
# 26                 Mac OS X, Windows 7 or newer
# 27                 Mac OS X, Windows 7 or newer
# 28                 Mac OS X, Windows 7 or newer
# 29                 Mac OS X, Windows 7 or newer
# 30                 Mac OS X, Windows 7 or newer
# 31                 Mac OS X, Windows 7 or newer
# 32                 Mac OS X, Windows 7 or newer
# 33                 Mac OS X, Windows 7 or newer
# 34                 Mac OS X, Windows 7 or newer
# 35                 Mac OS X, Windows 7 or newer
# 36                 Mac OS X, Windows 7 or newer
# 37                 Mac OS X, Windows 7 or newer
# 38                 Mac OS X, Windows 7 or newer
# 39                 Mac OS X, Windows 7 or newer
# 40                 Mac OS X, Windows 7 or newer
# 41                 Mac OS X, Windows 7 or newer
# 42                 Mac OS X, Windows 7 or newer
# 43                 Mac OS X, Windows 7 or newer
# 44                 Mac OS X, Windows 7 or newer
# 45                 Mac OS X, Windows 7 or newer
# 46                 Mac OS X, Windows 7 or newer
# 47                                         None
#
#                                                     2  \
# 0                                            Codename
# 1                                                Bond
# 2                                        October 1988
# 3                                              Seurat
# 4                                       February 1990
# 5                                           Fast Eddy
# 6                                              Merlin
# 7                                           Brimstone
# 8                                       November 1993
# 9                                      Tiger Mountain
# 10                                      November 1994
# 11                                   Big Electric Cat
# 12                                      Strange Cargo
# 13                                      Strange Cargo
# 14                                      Venus in Furs
# 15                                         Liquid Sky
# 16                                        August 2002
# 17                                        Dark Matter
# 18                                       Space Monkey
# 19                                           Red Pill
# 20                                         Stonehenge
# 21                                       White Rabbit
# 22                                       White Rabbit
# 23                                       Superstition
# 24                                            Lucky 7
# 25                                            Lucky 7
# 26                             Single Malt Wiskey Cat
# 27                             Single Malt Wiskey Cat
# 28                             Single Malt Wiskey Cat
# 29  Dedicated to Thomas and John Knoll (Adobe Phot...
# 30  Dedicated to Thomas and John Knoll (Adobe Phot...
# 31  Dedicated to Thomas and John Knoll (Adobe Phot...
# 32                                              Haiku
# 33                                              Haiku
# 34                                            Big Rig
# 35                                            Big Rig
# 36                                            Big Rig
# 37                                            Big Rig
# 38                                         White Lion
# 39                                         White Lion
# 40                                         White Lion
# 41                                         White Lion
# 42                                         White Lion
# 43                                         White Lion
# 44                                         White Lion
# 45                                         White Lion
# 46                                         White Lion
# 47                                               None
#
#                                                     3  \
# 0                                        Release date
# 1                                        January 1988
# 2
# 3                                          March 1989
# 4   Last release for System 6.0.3\nIn February 201...
# 5                                           June 1991
# 6                                       November 1992
# 7                                       November 1992
# 8
# 9                                      September 1994
# 10
# 11                                      November 1996
# 12                                           May 1998
# 13                                      February 1999
# 14                                     September 2000
# 15                                         March 2002
# 16  Camera RAW 1.x (optional plugin)\nLast release...
# 17                                       October 2003
# 18                                      April 4, 2005
# 19                                     April 16, 2007
# 20                                October 15, 2008[6]
# 21                                  April 30, 2010[7]
# 22                                     May 3, 2011[9]
# 23                                    May 7, 2012[10]
# 24                                      June 17, 2013
# 25                                     September 2013
# 26                                       January 2014
# 27                                          June 2014
# 28                                      December 2014
# 29                                      June 15, 2015
# 30                                  November 30, 2015
# 31                                   January 20, 2016
# 32                                  June 20, 2016[11]
# 33                                 August 8, 2016[12]
# 34                               November 2, 2016[13]
# 35                              December 16, 2016[14]
# 36                                  April 5, 2017[14]
# 37                                 April 25, 2017[14]
# 38                              October 18, 2017 [15]
# 39                             November 14, 2017 [16]
# 40                               January 14, 2018[17]
# 41                                 February, 2018[18]
# 42                                    March, 2018[18]
# 43                                    April, 2018[18]
# 44                                      May, 2018[18]
# 45                                     June, 2018[18]
# 46                                     July, 2018[18]
# 47                                               None
#
#                                                     4
# 0                       Notes and significant changes
# 1   Not publicly released - This demo was the firs...
# 2
# 3   First version distributed commercially (by the...
# 4
# 5   Paths\nCMYK Color\nEPS Rasterization\nLast rel...
# 6   16 bit per channel support\n"Deluxe" edition a...
# 7   16 bit per channel support\n"Deluxe" edition a...
# 8   16 bit per channel support\n"Deluxe" edition a...
# 9   Tabbed Palettes\nLayers\nLast release for Wind...
# 10  Tabbed Palettes\nLayers\nLast release for Wind...
# 11  Adjustment Layers\nActions (macros)\nNavigator...
# 12  Editable type (previously, type was rasterized...
# 13  Bundled with ImageReady\nSave for Web\nExtract...
# 14  Vector Shapes\nUpdated User Interface\n"Liquif...
# 15  Made text fully vector\nHealing Brush\nNew pai...
# 16
# 17   Adobe Photoshop CS\nCamera RAW 2.x\nHighly mo...
# 18   Adobe Photoshop CS2\nCamera RAW 3.x\nSmart Ob...
# 19   Adobe Photoshop CS3 Extended\nNative support ...
# 20  Smoother panning and zooming and fluid canvas ...
# 21  Content Aware Fill\nPuppet Warp Tool\n64 bit f...
# 22  Interacts with remote applications over TCP/IP...
# 23  UI redesign (all new icons and optional dark U...
# 24  Camera Shake Reduction\nFormer Extended featur...
# 25  Adobe Generator\nGenerate image assets from la...
# 26  Perspective Warp\nLinked smart objects\n3D Pri...
# 27  Blur Gallery motion effects\nFocus Mask\nExpan...
# 28     Last release for Windows 8 and Intel Pentium 4
# 29  Artboards\nAdobe Stock marketplace\nDesign Spa...
# 30  New Creative Cloud Libraries capabilities\nDes...
# 31  Crash Reporter: Crash when creating Character ...
# 32  Better collaboration with Libraries\nMatch Fon...
# 33  Keyboard shortcuts repaired\nFixed exporting n...
# 34  In-app search\nTighter integration with Adobe ...
# 35     Touch Bar support for Apple MacBook Pro\nFixes
# 36  Program error when converting to bitmap using ...
# 37  Scratch Disk size error\nNik Dfine 2 freezes o...
# 38  New Stroke smoothing features\nNew Curvature P...
# 39  This update includes a few (10+) changes for t...
# 40  This update includes many (40+) changes for th...
# 41  This update includes the following changes:\nC...
# 42  This update includes the following changes:\nT...
# 43  This update includes the following changes:\nI...
# 44  This update includes the following changes:\nE...
# 45  This update includes the following fixes:\nInv...
# 46  This update includes the following fixes:\nAft...
# 47                                               None

# %% [markdown]
# Export the dataframe to a csv.

# %%
df.to_csv('photoshop_versions.csv', sep=',')
